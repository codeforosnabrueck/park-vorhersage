# %% [markdown]
# # Exploring BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import urllib
from selenium import webdriver

# %%
url = ''
executable_path_geckodriver = r''

# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

options = Options()
options.headless = True
driver = webdriver.Firefox(options=options, executable_path=executable_path_geckodriver)

# %%
driver.get(url)
items = driver.find_element_by_class_name('parking-ramp-utilization')

# %%
#soup = BeautifulSoup(text, 'html.parser')

for item in soup.find_all('span', 'parking-ramp-utilization'):
    print(item.text)
# Out:
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
#                                     keine Info
#
#
# ...
